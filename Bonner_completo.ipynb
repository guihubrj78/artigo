# %% [markdown]
# <a href="https://colab.research.google.com/github/guihubrj78/artigo/blob/master/Bonner_completo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install deepface
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 65 kB 717 kB/s
# ...
#      |████████████████████████████████| 2.3 MB 9.2 MB/s
# ...
#      |████████████████████████████████| 87 kB 3.1 MB/s
# ...
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115943 sha256=9470f8059c6407ecf3ada37fbf4c076e223987b9e3fa201a5f325a092e5867af
#   Stored in directory: /root/.cache/pip/wheels/1f/10/06/2a990ee4d73a8479fe2922445e8a876d38cfbfed052284c6a1
# Successfully built fire
# ...

# %%
from deepface  import DeepFace
import cv2
import matplotlib.pyplot as plt
# Out:
# Directory  /root /.deepface created
# Directory  /root /.deepface/weights created

# %%
from google.colab import drive
drive.mount('/content/imagens',force_remount = True)
# Out:
# Mounted at /content/imagens

# %%
foto1 = '/content/imagens/MyDrive/database/bonner1.jpg'
#foto2 = '/content/imagens/MyDrive/database/bonner3.jpg'
#foto2 = '/content/imagens/MyDrive/database/juno.jpg'
#foto2 = '/content/imagens/MyDrive/database/bonner4.jpg'
foto2 = '/content/imagens/MyDrive/database/bonner8.jpg'

# %%
img1 = cv2.imread(foto1)
img2 = cv2.imread(foto2)

# %%
plt.imshow(img1[:, :,::-1])

# %%
plt.imshow(img2[:, :,::-1])

# %%
metrics = ["cosine", "euclidean", "euclidean_l2"]
models = ["VGG-Face", "Facenet", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]
def verify (img1,img2,valor1,valor2):
  plt.imshow(img1[:, :,::-1])
  plt.show()
  plt.imshow(img2[:, :,::-1])
  plt.show()
  saida = DeepFace.verify(img1,img2, model_name = models[valor1], distance_metric = metrics[valor2])
  print(saida)
  verificacao = saida['verified']
  if verificacao:
    print('São as mesmas pessoas')
  else:
    print('São pessoas diferentes')

# %% [markdown]
# **TREINO COM OPENFACE MODEL**

# %%
verify(img1,img2,2,0)
# Out:
# ...
# 1/1 [==============================] - 0s 46ms/step
# {'verified': False, 'distance': 0.10496554340650732, 'threshold': 0.1, 'model': 'OpenFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# São pessoas diferentes

# %%
verify(img1,img2,2,1)
# Out:
# ...
# 1/1 [==============================] - 0s 41ms/step
# {'verified': True, 'distance': 0.4581823631751691, 'threshold': 0.55, 'model': 'OpenFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean'}
# São as mesmas pessoas

# %%
verify(img1,img2,2,2)
# Out:
# ...
# 1/1 [==============================] - 0s 51ms/step
# {'verified': True, 'distance': 0.45818237287461705, 'threshold': 0.55, 'model': 'OpenFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean_l2'}
# São as mesmas pessoas

# %%
metrics = ["cosine", "euclidean", "euclidean_l2"]
models = ["VGG-Face", "Facenet", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]
resultado1 = DeepFace.verify(img1,img2, model_name = models[2], distance_metric = metrics[0])

resultado1
# Out:
# ...
# 1/1 [==============================] - 0s 48ms/step
# {'verified': False,
#  'distance': 0.10496554340650732,
#  'threshold': 0.1,
#  'model': 'OpenFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'cosine'}

# %%
metrics = ["cosine", "euclidean", "euclidean_l2"]
models = ["VGG-Face", "Facenet", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]
resultado2 = DeepFace.verify(img1,img2, model_name = models[2], distance_metric = metrics[1])

resultado2
# Out:
# ...
# 1/1 [==============================] - 0s 64ms/step
# {'verified': True,
#  'distance': 0.4581823631751691,
#  'threshold': 0.55,
#  'model': 'OpenFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'euclidean'}

# %%
metrics = ["cosine", "euclidean", "euclidean_l2"]
models = ["VGG-Face", "Facenet", "OpenFace", "DeepFace", "DeepID", "ArcFace", "Dlib"]
resultado3 = DeepFace.verify(img1,img2, model_name = models[2], distance_metric = metrics[2])

resultado3
# Out:
# ...
# 1/1 [==============================] - 0s 40ms/step
# {'verified': True,
#  'distance': 0.45818237287461705,
#  'threshold': 0.55,
#  'model': 'OpenFace',
#  'detector_backend': 'opencv',
#  'similarity_metric': 'euclidean_l2'}

# %%
result_analise_img1 = DeepFace.analyze(img1, actions = ['race', 'emotion','gender'])
print(result_analise_img1)
# Out:
# ...
# Action: gender: 100%|██████████| 3/3 [00:01<00:00,  1.61it/s]
# {'race': {'asian': 2.0011041313409805, 'indian': 3.05556058883667, 'black': 0.14933644561097026, 'white': 61.50449514389038, 'middle eastern': 22.504761815071106, 'latino hispanic': 10.78474298119545}, 'dominant_race': 'white', 'region': {'x': 147, 'y': 58, 'w': 210, 'h': 210}, 'emotion': {'angry': 91.74019694328308, 'disgust': 4.057173086380317e-06, 'fear': 6.54982402920723, 'happy': 0.011904805433005095, 'sad': 1.6967542469501495, 'surprise': 5.067893482646468e-06, 'neutral': 0.001308718947257148}, 'dominant_emotion': 'angry', 'gender': 'Woman'}

# %%
result_analise_img1['emotion']
# Out:
# {'angry': 91.74019694328308,
#  'disgust': 4.057173086380317e-06,
#  'fear': 6.54982402920723,
#  'happy': 0.011904805433005095,
#  'sad': 1.6967542469501495,
#  'surprise': 5.067893482646468e-06,
#  'neutral': 0.001308718947257148}

# %%
result_analise_img1['race']
# Out:
# {'asian': 2.0011041313409805,
#  'indian': 3.05556058883667,
#  'black': 0.14933644561097026,
#  'white': 61.50449514389038,
#  'middle eastern': 22.504761815071106,
#  'latino hispanic': 10.78474298119545}

# %%
result_analise_img1['gender']
# Out:
# 'Woman'

# %%
result_analise_img2 = DeepFace.analyze(img2, actions = ['race', 'emotion','gender'])

print(result_analise_img2)
# Out:
# ...
# Action: gender: 100%|██████████| 3/3 [00:02<00:00,  1.25it/s]
# {'race': {'asian': 1.084553636610508, 'indian': 0.28637947980314493, 'black': 0.02418610529275611, 'white': 85.6295645236969, 'middle eastern': 6.73389732837677, 'latino hispanic': 6.241415813565254}, 'dominant_race': 'white', 'region': {'x': 113, 'y': 75, 'w': 227, 'h': 227}, 'emotion': {'angry': 6.052050739526749, 'disgust': 8.207080154365443e-09, 'fear': 0.05400434019975364, 'happy': 3.949105291667365e-05, 'sad': 33.83638262748718, 'surprise': 8.774477672224279e-10, 'neutral': 60.05752682685852}, 'dominant_emotion': 'neutral', 'gender': 'Man'}

# %%
result_analise_img2['emotion']
# Out:
# {'angry': 6.052050739526749,
#  'disgust': 8.207080154365443e-09,
#  'fear': 0.05400434019975364,
#  'happy': 3.949105291667365e-05,
#  'sad': 33.83638262748718,
#  'surprise': 8.774477672224279e-10,
#  'neutral': 60.05752682685852}

# %%
result_analise_img2['race']
# Out:
# {'asian': 1.084553636610508,
#  'indian': 0.28637947980314493,
#  'black': 0.02418610529275611,
#  'white': 85.6295645236969,
#  'middle eastern': 6.73389732837677,
#  'latino hispanic': 6.241415813565254}

# %%
result_analise_img2['gender']
# Out:
# 'Woman'

# %% [markdown]
# **TREINO COM VGG**

# %%
verify(img1,img2,0,0)
# Out:
# ...
# 1/1 [==============================] - 1s 645ms/step
# {'verified': True, 'distance': 0.06702230840704881, 'threshold': 0.4, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# São as mesmas pessoas

# %%
verify(img1,img2,0,1)
# Out:
# ...
# 1/1 [==============================] - 1s 619ms/step
# {'verified': True, 'distance': 0.18561467433951379, 'threshold': 0.6, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean'}
# São as mesmas pessoas

# %%
verify(img1,img2,0,2)
# Out:
# ...
# 1/1 [==============================] - 1s 782ms/step
# {'verified': True, 'distance': 0.3661210412064535, 'threshold': 0.86, 'model': 'VGG-Face', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean_l2'}
# São as mesmas pessoas

# %% [markdown]
# **TREINO COM FACENET**

# %%
verify(img1,img2,1,0)
# Out:
# ...
# 1/1 [==============================] - 0s 109ms/step
# {'verified': True, 'distance': 0.08141384643339244, 'threshold': 0.4, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# São as mesmas pessoas

# %%
verify(img1,img2,1,1)
# Out:
# ...
# 1/1 [==============================] - 0s 116ms/step
# {'verified': True, 'distance': 2.1138090836058834, 'threshold': 10, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean'}
# São as mesmas pessoas

# %%
verify(img1,img2,1,2)
# Out:
# ...
# 1/1 [==============================] - 0s 103ms/step
# {'verified': True, 'distance': 0.4035191356884881, 'threshold': 0.8, 'model': 'Facenet', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean_l2'}
# São as mesmas pessoas

# %% [markdown]
# **TREINO COM DEEPFACE**

# %%
verify(img1,img2,3,0)
# Out:
# ...
# 1/1 [==============================] - 0s 149ms/step
# {'verified': True, 'distance': 0.18467647477279314, 'threshold': 0.23, 'model': 'DeepFace', 'detector_backend': 'opencv', 'similarity_metric': 'cosine'}
# São as mesmas pessoas

# %%
verify(img1,img2,3,1)
# Out:
# ...
# 1/1 [==============================] - 0s 135ms/step
# {'verified': True, 'distance': 41.25470462875555, 'threshold': 64, 'model': 'DeepFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean'}
# São as mesmas pessoas

# %%
verify(img1,img2,3,2)
# Out:
# ...
# 1/1 [==============================] - 0s 116ms/step
# {'verified': True, 'distance': 0.607744148096538, 'threshold': 0.64, 'model': 'DeepFace', 'detector_backend': 'opencv', 'similarity_metric': 'euclidean_l2'}
# São as mesmas pessoas
